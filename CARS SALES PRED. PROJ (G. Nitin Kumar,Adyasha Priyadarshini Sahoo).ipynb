# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#reading dataset
cars=pd.read_csv(r"C:\Users\Srinivasa Rao\OneDrive\Desktop\car sales.csv")
cars
# Out:
#        BMW  SUPRA   GTR  Sales
# 0    230.1   37.8  69.2   22.1
# 1     44.5   39.3  45.1   10.4
# 2     17.2   45.9  69.3   12.0
# 3    151.5   41.3  58.5   16.5
# 4    180.8   10.8  58.4   17.9
# ..     ...    ...   ...    ...
# 195   38.2    3.7  13.8    7.6
# 196   94.2    4.9   8.1   14.0
# 197  177.0    9.3   6.4   14.8
# 198  283.6   42.0  66.2   25.5
# 199  232.1    8.6   8.7   18.4
#
# [200 rows x 4 columns]

# %%
#data cleaning
cars.isnull().sum()
# Out:
# BMW      0
# SUPRA    0
# GTR      0
# Sales    0
# dtype: int64

# %%
cars.dtypes
# Out:
# BMW      float64
# SUPRA    float64
# GTR      float64
# Sales    float64
# dtype: object

# %%
for i in cars.columns:
    print(i,':','\n',oly[i].unique(),'\n')
# Out:
# BMW :
#  [230.1  44.5  17.2 151.5 180.8   8.7  57.5 120.2   8.6 199.8  66.1 214.7
#   23.8  97.5 204.1 195.4  67.8 281.4  69.2 147.3 218.4 237.4  13.2 228.3
#   62.3 262.9 142.9 240.1 248.8  70.6 292.9 112.9  97.2 265.6  95.7 290.7
#  266.9  74.7  43.1 228.  202.5 177.  293.6 206.9  25.1 175.1  89.7 239.9
#  227.2  66.9 100.4 216.4 182.6 262.7 198.9   7.3 136.2 210.8 210.7  53.5
#  261.3 239.3 102.7 131.1  69.   31.5 139.3 216.8 199.1 109.8  26.8 129.4
#  213.4  16.9  27.5 120.5   5.4 116.   76.4 239.8  75.3  68.4 213.5 193.2
#   76.3 110.7  88.3 134.3  28.6 217.7 250.9 107.4 163.3 197.6 184.9 289.7
#  135.2 222.4 296.4 280.2 187.9 238.2 137.9  25.   90.4  13.1 255.4 225.8
#  241.7 175.7 209.6  78.2  75.1 139.2 125.7  19.4 141.3  18.8 224.  123.1
#  229.5  87.2   7.8  80.2 220.3  59.6   0.7 265.2   8.4 219.8  36.9  48.3
#   25.6 273.7  43.   73.4 193.7 220.5 104.6  96.2 140.3 243.2  38.   44.7
#  280.7 121.  171.3 187.8   4.1  93.9 149.8  11.7 131.7 172.5  85.7 188.4
# ...

# %%
#describe
cars.describe(include='all')
# Out:
#               BMW       SUPRA         GTR       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
#data  analysis
sns.scatterplot(x=cars.GTR,y=cars.Sales)
plt.show()

# %%
sns.scatterplot(x=oly.SUPRA,y=oly.Sales)
plt.show()

# %%
sns.scatterplot(x=oly.BMW,y=oly.Sales)
plt.show()

# %%
sns.histplot(data=cars)
plt.show()
# Out:
# C:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.kdeplot(data=cars,fill=True)
plt.show()
# Out:
# C:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.jointplot(data=cars)
plt.show()
# Out:
# C:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.scatterplot(x=cars.BMW,y=oly.SUPRA,hue=cars.Sales)
plt.show()

# %%
sns.scatterplot(x=cars.BMW,y=cars.GTR,hue=cars.Sales)
plt.show()

# %%
sns.scatterplot(x=cars.SUPRA,y=cars.GTR,hue=cars.Sales)
plt.show()

# %%
sns.pairplot(cars,hue='Sales')
plt.show()
# Out:
# C:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
c= cars.corr()
c
# Out:
#             BMW     SUPRA       GTR     Sales
# BMW    1.000000  0.054809  0.056648  0.901208
# SUPRA  0.054809  1.000000  0.354104  0.349631
# GTR    0.056648  0.354104  1.000000  0.157960
# Sales  0.901208  0.349631  0.157960  1.000000

# %%
sns.heatmap(c,annot=True)
plt.show()

# %%
#ip/op creation
ip=cars.drop('Sales',axis=1)
op=cars.Sales

# %%
ip.head()
# Out:
#      BMW  SUPRA   GTR
# 0  230.1   37.8  69.2
# 1   44.5   39.3  45.1
# 2   17.2   45.9  69.3
# 3  151.5   41.3  58.5
# 4  180.8   10.8  58.4

# %%
op.head()
# Out:
# 0    22.1
# 1    10.4
# 2    12.0
# 3    16.5
# 4    17.9
# Name: Sales, dtype: float64

# %%
#train test split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(ip,op,test_size=0.2,random_state=0)

# %%
x_train
# Out:
#        BMW  SUPRA   GTR
# 134   36.9   38.6  65.6
# 66    31.5   24.6   2.2
# 26   142.9   29.3  12.6
# 113  209.6   20.6  10.7
# 168  215.4   23.6  57.6
# ..     ...    ...   ...
# 67   139.3   14.5  10.2
# 192   17.2    4.1  31.6
# 117   76.4    0.8  14.8
# 47   239.9   41.5  18.5
# 172   19.6   20.1  17.0
#
# [160 rows x 3 columns]

# %%
x_test
# Out:
#        BMW  SUPRA    GTR
# 18    69.2   20.5   18.3
# 170   50.0   11.6   18.4
# 107   90.4    0.3   23.2
# 98   289.7   42.3   51.2
# 177  170.2    7.8   35.2
# 182   56.2    5.7   29.7
# 5      8.7   48.9   75.0
# 146  240.1    7.3    8.7
# 12    23.8   35.1   65.9
# 152  197.6   23.3   14.2
# 61   261.3   42.7   54.7
# 125   87.2   11.8   25.9
# 180  156.6    2.6    8.3
# 154  187.8   21.1    9.5
# 80    76.4   26.7   22.3
# 7    120.2   19.6   11.6
# 33   265.6   20.0    0.3
# 130    0.7   39.6    8.7
# 37    74.7   49.4   45.7
# 74   213.4   24.6   13.1
# 183  287.6   43.0   71.8
# 145  140.3    1.9    9.0
# 45   175.1   22.5   31.5
# 159  131.7   18.4   34.6
# 60    53.5    2.0   21.4
# 123  123.1   34.6   12.4
# 179  165.6   10.0   17.6
# 185  205.0   45.1   19.6
# 122  224.0    2.4   15.6
# 44    25.1   25.7   43.3
# 16    67.8   36.6  114.0
# 55   198.9   49.4   60.0
# 150  280.7   13.9   37.0
# 111  241.7   38.0   23.2
# 22    13.2   15.9   49.6
# 189   18.7   12.1   23.4
# ...

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_train.shape)
# Out:
# (160, 3)
# (40, 3)
# (160,)
# (160,)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
x_train
# Out:
# array([[-1.34155345,  1.0355176 ,  1.65941078],
#        [-1.4053143 ,  0.08249594, -1.30629738],
#        [-0.08995151,  0.40243892, -0.81980897],
#        [ 0.69761311, -0.18979597, -0.90868666],
#        [ 0.76609699,  0.01442296,  1.28518893],
#        [-0.56461564,  0.42286082, -1.01627544],
#        [-1.67570755, -1.44914602, -1.36243065],
#        [-1.57770476,  1.38268978,  2.77272078],
#        [-0.29304164,  0.91979354,  2.29558792],
#        [-0.54218127, -1.20408331,  0.19994556],
#        [-0.48078193, -0.61865571,  0.07364569],
#        [ 0.93258366,  0.60665785,  2.06169926],
#        [ 1.2195075 , -0.14214488, -0.00587645],
#        [ 0.40596624, -0.16256678, -0.3800983 ],
#        [-1.24945444,  0.16418351, -0.44558712],
#        [-1.04164129, -0.73437977, -0.55317591],
#        [ 1.68118331,  0.33436595,  0.6115896 ],
#        [ 0.25955243, -0.35997841,  0.02686796],
#        [ 0.61377939, -0.07407191,  0.06896792],
#        [-1.69105739,  0.32075135,  0.52738968],
# ...

# %%
#ML model
#linear regression
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred=lr.predict(x_test)
pred
# Out:
# array([11.85347427,  9.90588017, 10.76558383, 25.4808191 , 15.65528291,
#         9.55629711, 11.58893696, 19.30070192, 10.9182702 , 18.80314052,
#        24.04456877, 11.82536588, 14.48233323, 18.0759572 , 12.8777854 ,
#        14.41451549, 22.00875284, 10.39418189, 15.14925121, 19.76278563,
#        25.38009928, 13.56253618, 17.49795821, 14.80493919,  9.04685529,
#        16.17131801, 15.71111771, 21.50713724, 17.92031345, 10.05064533,
#        13.19603579, 21.52129568, 22.014685  , 22.63021387,  8.36349314,
#         8.32558497, 10.36424063, 16.44921208, 14.33087568,  8.51255875])

# %%
y_test
# Out:
# 18     11.3
# 170     8.4
# 107    12.0
# 98     25.4
# 177    16.7
# 182     8.7
# 5       7.2
# 146    18.2
# 12      9.2
# 152    16.6
# 61     24.2
# 125    10.6
# 180    15.5
# 154    20.6
# 80     11.8
# 7      13.2
# 33     17.4
# 130     1.6
# 37     14.7
# 74     17.0
# 183    26.2
# 145    10.3
# 45     16.1
# 159    12.9
# 60      8.1
# 123    15.2
# 179    17.6
# 185    22.6
# 122    16.6
# 44      8.5
# 16     12.5
# 55     23.7
# 150    16.1
# 111    21.8
# 22      5.6
# 189     6.7
# 129     9.7
# 4      17.9
# 83     13.6
# 106     7.2
# Name: Sales, dtype: float64

# %%
#Accuracy
from sklearn.metrics import mean_squared_error,r2_score
mse=mean_squared_error(pred,y_test)
r2=r2_score(pred,y_test)

print('Mean Square Error: ',mse)
print('r2 Score: ',r2)
# Out:
# Mean Square Error:  5.895680572900137
# r2 Score:  0.7608459324374706

# %%
df=pd.DataFrame({'y_test':list(y_test),'Prediction':pred})
df
# Out:
#     y_test  Prediction
# 0     11.3   11.853474
# 1      8.4    9.905880
# 2     12.0   10.765584
# 3     25.4   25.480819
# 4     16.7   15.655283
# 5      8.7    9.556297
# 6      7.2   11.588937
# 7     18.2   19.300702
# 8      9.2   10.918270
# 9     16.6   18.803141
# 10    24.2   24.044569
# 11    10.6   11.825366
# 12    15.5   14.482333
# 13    20.6   18.075957
# 14    11.8   12.877785
# 15    13.2   14.414515
# 16    17.4   22.008753
# 17     1.6   10.394182
# 18    14.7   15.149251
# 19    17.0   19.762786
# 20    26.2   25.380099
# 21    10.3   13.562536
# 22    16.1   17.497958
# 23    12.9   14.804939
# 24     8.1    9.046855
# 25    15.2   16.171318
# 26    17.6   15.711118
# 27    22.6   21.507137
# 28    16.6   17.920313
# 29     8.5   10.050645
# 30    12.5   13.196036
# 31    23.7   21.521296
# 32    16.1   22.014685
# 33    21.8   22.630214
# 34     5.6    8.363493
# 35     6.7    8.325585
# 36     9.7   10.364241
# 37    17.9   16.449212
# 38    13.6   14.330876
# ...

# %%
sns.lmplot(x='y_test',y='Prediction',data=df)
plt.show()
